# %%
import  pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MaxNLocator

# %%
df = pd.read_csv('red_wine.csv')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# 3      9.8      6.0
# 4      9.4      5.0
# 5      9.4      5.0
# 6      9.4      5.0
# 7     10.0      7.0
# 8      9.5      7.0
# 9     10.5      5.0

# %%
df.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1579     11.3      5.0
# 1580     11.9      6.0
# 1581     11.3      5.0
# 1582     11.9      5.0
# 1583      9.8      5.0
# 1584     11.6      7.0
# 1585     11.5      6.0
# 1586     11.4      6.0
# 1587     10.9      6.0
# 1588     12.8      6.0
# 1589      9.2      5.0
# 1590     11.6      6.0
# 1591     11.6      6.0
# 1592     11.0      6.0
# 1593      9.5      6.0
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997830
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1598.000000
# mean      3.311113     0.658149    10.422983     5.635795
# std       0.154386     0.169507     1.065668     0.807771
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.shape
# Out:
# (1599, 12)

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['density'], df['residual sugar'], marker='o', color='g', linestyle='-')
plt.title('Line plot of dataset')
plt.xlabel('density')
plt.ylabel('residual sugar')
plt.grid(True)
plt.show()

# %%
df.quality.value_counts()
# Out:
# quality
# 5.0    681
# 6.0    637
# 7.0    199
# 4.0     53
# 8.0     18
# 3.0     10
# Name: count, dtype: int64

# %%
df['fixed acidity'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['volatile acidity'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['volatile acidity'].min())
print('Max value', df['volatile acidity'].max())
# Out:
# Min value 0.12
# Max value 1.58

# %%
df['citric acid'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['residual sugar'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['residual sugar'].min())
print('Max value',df['residual sugar'].max())
# Out:
# Min value 0.9
# Max value 15.5

# %%
df['chlorides'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['chlorides'].min())
print('Max value',df['chlorides'].max())
# Out:
# Min value 0.012
# Max value 0.611

# %%
df['free sulfur dioxide'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['free sulfur dioxide'].min())
print('Max value',df['free sulfur dioxide'].max())
# Out:
# Min value 1.0
# Max value 72.0

# %%
df['total sulfur dioxide'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['total sulfur dioxide'].min())
print('Max value',df['total sulfur dioxide'].max())
# Out:
# Min value 6.0
# Max value 289.0

# %%
df['density'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['density'].min())
print('Max value',df['density'].max())
# Out:
# Min value 0.99007
# Max value 1.00369

# %%
df['pH'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['pH'].min())
print('Max value',df['pH'].max())
# Out:
# Min value 2.74
# Max value 4.01

# %%
df['sulphates'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['sulphates'].min())
print('Max value',df['sulphates'].max())
# Out:
# Min value 0.33
# Max value 2.0

# %%
df['alcohol'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print('Min value',df['alcohol'].min())
print('Max value',df['alcohol'].max())
# Out:
# Min value 8.4
# Max value 14.9

# %%
sns.scatterplot(x='density', y='alcohol', data=df)
# Out:
# <Axes: xlabel='density', ylabel='alcohol'>

# %%
sns.scatterplot(x='pH', y='alcohol', data=df)
# Out:
# <Axes: xlabel='pH', ylabel='alcohol'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'fixed acidity', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'citric acid', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'sulphates', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'alcohol', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'pH', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(method='pearson'), annot=True, square=True)
plt.show()

# %%
print('Another view of correlations among features:\n')
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# Another view of correlations among features:
# <style type="text/css">
# #T_39fb4_row0_col0, #T_39fb4_row1_col1, #T_39fb4_row2_col2, #T_39fb4_row3_col3, #T_39fb4_row4_col4, #T_39fb4_row5_col5, #T_39fb4_row6_col6, #T_39fb4_row7_col7, #T_39fb4_row8_col8, #T_39fb4_row9_col9, #T_39fb4_row10_col10, #T_39fb4_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col1, #T_39fb4_row4_col11, #T_39fb4_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_39fb4_row0_col5, #T_39fb4_row0_col8, #T_39fb4_row1_col2, #T_39fb4_row1_col9, #T_39fb4_row1_col11, #T_39fb4_row2_col1, #T_39fb4_row7_col10, #T_39fb4_row8_col0, #T_39fb4_row8_col3, #T_39fb4_row8_col4, #T_39fb4_row10_col6, #T_39fb4_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_39fb4_row0_col9, #T_39fb4_row3_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_39fb4_row0_col10, #T_39fb4_row3_col11 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_39fb4_row0_col11, #T_39fb4_row2_col4, #T_39fb4_row7_col1, #T_39fb4_row7_col4, #T_39fb4_row10_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_39fb4_row1_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_39fb4_row1_col3, #T_39fb4_row2_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_39fb4_row1_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_39fb4_row1_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_39fb4_row1_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_39fb4_row1_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_39fb4_row1_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_39fb4_row1_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_39fb4_row2_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_39fb4_row2_col3, #T_39fb4_row3_col9, #T_39fb4_row5_col4, #T_39fb4_row11_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_39fb4_row2_col6, #T_39fb4_row7_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_39fb4_row2_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_39fb4_row2_col8, #T_39fb4_row9_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_39fb4_row2_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_39fb4_row2_col10, #T_39fb4_row6_col1, #T_39fb4_row7_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_39fb4_row2_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_39fb4_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_39fb4_row3_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_39fb4_row3_col2, #T_39fb4_row5_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_39fb4_row3_col4, #T_39fb4_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_39fb4_row3_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_39fb4_row3_col6, #T_39fb4_row6_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_39fb4_row3_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_39fb4_row3_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_39fb4_row4_col0, #T_39fb4_row9_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_39fb4_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_39fb4_row4_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_39fb4_row4_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_39fb4_row4_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_39fb4_row4_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_39fb4_row4_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_39fb4_row4_col8, #T_39fb4_row5_col9, #T_39fb4_row6_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_39fb4_row4_col9, #T_39fb4_row9_col4, #T_39fb4_row11_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_39fb4_row4_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_39fb4_row5_col0, #T_39fb4_row5_col2, #T_39fb4_row5_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_39fb4_row5_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_39fb4_row5_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_39fb4_row5_col10, #T_39fb4_row9_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_39fb4_row5_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_39fb4_row6_col2, #T_39fb4_row6_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_39fb4_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_39fb4_row6_col5 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_39fb4_row6_col8 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_39fb4_row6_col9, #T_39fb4_row8_col11 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_39fb4_row6_col10, #T_39fb4_row8_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_39fb4_row6_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_39fb4_row7_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_39fb4_row7_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_39fb4_row7_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_39fb4_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_39fb4_row7_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_39fb4_row7_col11 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_39fb4_row8_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_39fb4_row8_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_39fb4_row8_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_39fb4_row8_col7, #T_39fb4_row11_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_39fb4_row8_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_39fb4_row8_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_39fb4_row9_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_39fb4_row9_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_39fb4_row9_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_39fb4_row9_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_39fb4_row9_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_39fb4_row9_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_39fb4_row10_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_39fb4_row10_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_39fb4_row10_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_39fb4_row10_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_39fb4_row10_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_39fb4_row10_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_39fb4_row10_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_39fb4_row10_col11 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_39fb4_row11_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_39fb4_row11_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_39fb4_row11_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_39fb4_row11_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_39fb4_row11_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_39fb4_row11_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_39fb4_row11_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_39fb4_row11_col10 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# </style>
# <table id="T_39fb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39fb4_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_39fb4_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_39fb4_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_39fb4_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_39fb4_level0_col4" class="col_heading l

# %%
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# 3      9.8     bad
# 4      9.4     bad

# %%
df['quality'] = df['quality'].map({'bad' : 0, 'good' : 1})
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol quality
# 0      9.4       0
# 1      9.8       0
# 2      9.8       0
# 3      9.8       0
# 4      9.4       0
# 5      9.4       0
# 6      9.4       0
# 7     10.0       1
# 8      9.5       1
# 9     10.5       0

# %%
print(df['quality'].value_counts())
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(18, 5))
ax = ax.flatten()
df['quality'].value_counts().plot(x=0, y=1, kind='pie', figsize=(15,5), ax=ax[0])
sns.countplot(df['quality'], ax=ax[1])
plt.show()
# Out:
# quality
# 0    1381
# 1     217
# Name: count, dtype: int64
